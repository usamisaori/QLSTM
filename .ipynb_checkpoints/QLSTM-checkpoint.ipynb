# %%
import math
import time
import pickle
import pandas as pd
import numpy as np
np.set_printoptions(suppress = True)

# %%
import torch
import sklearn

# %%
from pyqpanda import *

# %%
# %matplotlib inline

# %% [markdown]
# # 1. Prepare Dadaset

# %%
# https://www.kaggle.com/datasets/sumanthvrao/daily-climate-time-series-data

# %%
train_path = './data/DailyDelhiClimateTrain.csv'
test_path = './data/DailyDelhiClimateTest.csv'

# %%
cols = [1,2,3,4]

train = pd.read_csv(train_path, usecols=cols, engine="python")
test = pd.read_csv(test_path, usecols=cols, engine="python")

# %%
print(f'len(train)={len(train)}')
print(f'len(test)={len(test)}')
# Out:
# len(train)=1462
# len(test)=114

# %% [markdown]
# ## 1.1 Outlier Detection

# %% [markdown]
# ### 1.1.1 outlier detection for train

# %%
plt.scatter(range(len(train)), train["meanpressure"])

# %% [markdown]
# ### - remove outliers

# %%
unnormal_num = 0
for i in range(len(train)):
    mp = train.iloc[i][3]
    if mp > 1200 or mp < 950:
        unnormal_num += 1
        train.iloc[i][3] = train.iloc[i + 1][3]
print(f'remove outliers num: {unnormal_num}')
# Out:
# remove outliers num: 9

# %%
plt.plot(train)
# Out:
# [<matplotlib.lines.Line2D at 0x16ec3ee2c70>,
#  <matplotlib.lines.Line2D at 0x16ec3ee2d90>,
#  <matplotlib.lines.Line2D at 0x16ec3ee2e50>,
#  <matplotlib.lines.Line2D at 0x16ec3ee2f10>]

# %%
train.describe().transpose()
# Out:
#                count         mean        std         min          25%  \
# meantemp      1462.0    25.495521   7.348103    6.000000    18.857143
# humidity      1462.0    60.771702  16.769652   13.428571    50.375000
# wind_speed    1462.0     6.802209   4.561602    0.000000     3.475000
# meanpressure  1462.0  1008.247674   7.437992  991.375000  1001.625000
#
#                       50%          75%          max
# meantemp        27.714286    31.305804    38.714286
# humidity        62.625000    72.218750   100.000000
# wind_speed       6.221667     9.238235    42.220000
# meanpressure  1008.563492  1014.875000  1023.000000

# %%
train[0:1]
# Out:
#    meantemp  humidity  wind_speed  meanpressure
# 0      10.0      84.5         0.0   1015.666667

# %% [markdown]
# ### 1.1.2 outlier detection for test

# %%
plt.scatter(range(len(test)), test["meanpressure"])

# %% [markdown]
# ### - remove outliers

# %%
test.iloc[0][3] = test.iloc[1][3]

# %%
plt.plot(test)
# Out:
# [<matplotlib.lines.Line2D at 0x16ec3fccbb0>,
#  <matplotlib.lines.Line2D at 0x16ec3fcccd0>,
#  <matplotlib.lines.Line2D at 0x16ec3fccd90>,
#  <matplotlib.lines.Line2D at 0x16ec3fcce50>]

# %% [markdown]
# ## 1.2 Transfer data to LSTM representation

# %%
from sklearn.preprocessing import StandardScaler

# %%
def data_process(data, window_size, predict_size):
    scaler = StandardScaler()
    data = scaler.fit_transform(np.array(data).reshape(-1, 1))
    
    data_in = []
    data_out = []
    
    for i in range(data.shape[0] - window_size - predict_size + 1):
        data_in.append(data[i:i + window_size].reshape(1, window_size)[0])
        data_out.append(data[i + window_size:i + window_size + predict_size].reshape(1, predict_size)[0])
        
    data_in = np.array(data_in).reshape(-1, window_size)
    data_out = np.array(data_out).reshape(-1, predict_size)
    
    data_process = {'datain': data_in, 'dataout': data_out}
    
    return data_process, scaler

# %% [markdown]
# ## 1.3 prepare train/test dataset

# %%
features_size = 4
window_size = features_size * 3 # features num * time steps
predict_size = features_size # features

# %%
train_processed, train_scaler = data_process(train, window_size, predict_size)
X_train, y_train = train_processed['datain'], train_processed['dataout']

test_processed, test_scaler = data_process(test, window_size, predict_size)
X_test, y_test = test_processed['datain'], test_processed['dataout']

# %%
X_train = torch.from_numpy(X_train.astype(np.float32))
X_test = torch.from_numpy(X_test.astype(np.float32))

y_train = torch.from_numpy(y_train.astype(np.float32))
y_test = torch.from_numpy(y_test.astype(np.float32))

# %% [markdown]
# ### - data loader

# %%
import torch.utils.data as Data

train_data = Data.TensorDataset(X_train, y_train)
test_data = Data.TensorDataset(X_test, y_test)

# %%
print(f'size of train_data: {len(train_data)}')
print(f'size of test_data: {len(test_data)}')
# Out:
# size of train_data: 5833
# size of test_data: 441

# %%
train_data[0]
# Out:
# (tensor([-0.6262, -0.4504, -0.6498,  1.7473, -0.6323, -0.4327, -0.6428,  1.7523,
#          -0.6329, -0.4445, -0.6389,  1.7543]),
#  tensor([-0.6293, -0.4814, -0.6469,  1.7508]))

# %%
test_data[0]
# Out:
# (tensor([-0.6067, -0.4426, -0.6376,  1.7437, -0.6006, -0.4629, -0.6372,  1.7437,
#          -0.6039, -0.4520, -0.6346,  1.7438]),
#  tensor([-0.6001, -0.4797, -0.6333,  1.7377]))

# %% [markdown]
# # 2. Quantum Enhanced LSTM

# %% [markdown]
# ## 2.1 initiate quantum environment

# %%
class InitQMachine:
    def __init__(self, qubitsCount, cbitsCount = 0, machineType = QMachineType.CPU):
        self.machine = init_quantum_machine(machineType)
        
        self.qubits = self.machine.qAlloc_many(qubitsCount)
        self.cbits = self.machine.cAlloc_many(cbitsCount)
        
        print(f'Init Quantum Machine with qubits:[{qubitsCount}] / cbits:[{cbitsCount}] Successfully')
    
    def __del__(self):
        destroy_quantum_machine(self.machine)

# %%
# maximum qubits size
ctx = InitQMachine(5)
# Out:
# Init Quantum Machine with qubits:[5] / cbits:[0] Successfully

# %% [markdown]
# ## 2.2 Quantum Layer

# %% [markdown]
# ### - Tool Functions

# %%
def draw(prog, filename=''):
    dir_path = './images/'
    
    if filename != '':
        draw_qprog(prog, 'pic', filename=f'{dir_path}{filename}')

# %% [markdown]
# ### 2.2.1 Quantum Layer Base

# %%
import torch.nn as nn
from torch import Tensor
from torch.nn import Parameter

# %%
class QuantumLayerBase(nn.Module):
    def __init__(self, input_size, output_size, *, n_qubits, n_layers = 1, ctx = None):
        super(QuantumLayerBase, self).__init__()
        
        self.data = None # need to input during forward
    
        self.input_size = input_size
        self.output_size = output_size # hidden size, not n_qubits
        
        # quantum infos
        self.n_qubits = n_qubits
        self.n_layers = n_layers
        
        self.ctx = ctx
        self.qubits = ctx.qubits
        self.machine = ctx.machine
        
        # convert quantum input/output to match classical computation
        self.qin = nn.Linear(self.input_size, self.n_qubits)
        self.qout = nn.Linear(self.n_qubits, self.output_size)
        
    @property
    def circuit(self):
        raise NotImplementedError('Should init circuit')

# %%
def measure(self):
    HamiZ = [ PauliOperator({f'Z{i}': 1}) for i in range(len(self.qubits)) ]
    res = [ eval(qop(self.circuit, Hami, self.machine, self.qubits))[0,0] for Hami in HamiZ ]
    
    return Parameter(Tensor(res[:self.n_qubits]))

QuantumLayerBase.measure = measure

# %%
def forward(self, inputs):
    y_t = self.qin(Parameter(inputs))
    self.data = y_t[0]
    
    return self.qout(self.measure())

QuantumLayerBase.forward = forward

# %% [markdown]
# ### 2.2.2 Quantum Layer Design

# %%
class QuantumLayer(QuantumLayerBase):
    def __init__(self, input_size, output_size, *, n_qubits, degree = 1, n_layers = 1, ctx = None):
        super(QuantumLayer, self).__init__(input_size, output_size, 
                                         n_qubits = n_qubits, n_layers = n_layers, ctx = ctx)
        
        self.degree = degree
        self.angles = Parameter(torch.rand(n_layers + 1, degree, self.n_qubits))
        
    @property
    def qparameters_size(self):
        return self.angles.flatten().size()[0]
        
    @property
    def circuit(self):
        if self.data == None:
            raise ValueError('Need to feed a input data!')
        
        n = self.n_qubits
        q = self.qubits
        x = self.data
        p = self.angles
        degree = self.degree
        
        # quantum gates - must use small case!
        identity = VariationalQuantumGate_I
        h = VariationalQuantumGate_H
        ry = VariationalQuantumGate_RY
        cz = VariationalQuantumGate_CZ
        u = [
            None,
            VariationalQuantumGate_U1,
            VariationalQuantumGate_U2,
            VariationalQuantumGate_U3
        ]
        
        # init variational quantum circuit
        vqc = VariationalQuantumCircuit()

        # in order to use each qubits => when n_qubits < len(ctx.qubits)
        [ vqc.insert(identity(q[i])) for i in range(len(q)) ]
        
        [ vqc.insert( h(q[i]) ) for i in range(n) ]
        [ vqc.insert( ry(q[i], var(x[i] * torch.pi/2)) ) for i in range(n) ]
        [ vqc.insert( u[degree](q[i], *[ var(p[0][d][i]) for d in range(degree) ]) ) 
                 for i in range(n) ]
        
        for layer in range(self.n_layers):
            for i in range(n - 1):
                vqc.insert(cz(q[i], q[i + 1]))
            vqc.insert(cz(q[n - 1], q[0]))
            
            [ vqc.insert( u[degree](q[i], *[ var(p[layer + 1][d][i]) for d in range(degree) ]) ) 
                 for i in range(n) ]
        
        return vqc

# %% [markdown]
# ## 2.3 Quantum-LSTM

# %%
class QLSTMBase(nn.Module):
    def __init__(self, input_size, hidden_size, *, ctx):
        super().__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.ctx = ctx
        
    @property
    def qparameters_size(self):
        num = 0
        for attr in dir(self):
            if attr.endswith('_circuit'):
                num += getattr(self, attr).qparameters_size
        return num

# %%
def forward(self, inputs, init_states = None):
    sequence_size, batch_size, _ = inputs.size()
    hidden_sequence = []
    
    if init_states == None:
        h_t, c_t = (
            torch.zeros(1, batch_size, self.hidden_size).to(inputs.device),
            torch.zeros(1, batch_size, self.hidden_size).to(inputs.device),
        )
    else:
        h_t, c_t = init_states
    
    return hidden_sequence, (h_t, c_t)

QLSTMBase.forward = forward

# %% [markdown]
# ### 2.3.1 classical Quantum-LSTM

# %%
class QLSTM(QLSTMBase):
    def __init__(self, input_size, hidden_size, *, ctx):
        super().__init__(input_size, hidden_size, ctx = ctx)
        
        # Parameters: angles
        #  => Q * (n + 1) * degree
        
        # gates names:  qubits  layers  degree
        # input gate:     5       2       3
        # forget gate:    5       2       3
        # candidate:      5       2       3
        # output gate:    5       2       3
        
        # input gates
        self.input_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                        n_qubits = 5, n_layers = 2, degree = 3, ctx = ctx) # 45
        # forget gates
        self.forget_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                         n_qubits = 5, n_layers = 2, degree = 3, ctx = ctx) # 45
        # candidate
        self.candidate_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                       n_qubits = 5, n_layers = 2, degree = 3, ctx = ctx) # 45
        # output gates
        self.output_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                         n_qubits = 5, n_layers = 2, degree = 3, ctx = ctx) # 45
        
    def forward(self, inputs, init_states = None):
        hidden_sequence, (h_t, c_t) = super(QLSTM, self).forward(inputs, init_states)

        for t in range(inputs.size()[0]):
            x_t = inputs[t, :, :]
            v_t = torch.cat((h_t[0], x_t), dim = 1)

            # input gates
            i_t = torch.sigmoid(self.input_circuit(v_t))
            # forget gates
            f_t = torch.sigmoid(self.forget_circuit(v_t))
            # candidate for cell state update
            g_t = torch.tanh(self.candidate_circuit(v_t))
            c_t = (f_t * c_t) + (i_t * g_t)

            # output gates
            o_t = torch.sigmoid(self.output_circuit(v_t))
            # update output ht
            h_t = o_t * (torch.tanh(c_t))

            hidden_sequence.append(h_t)

        # reshape hidden_seq p/ retornar
        #
        # [tensor([[[0.0444, ...]]] => tensor([[[0.0444, ...]]]
        # 
        hidden_sequence = torch.cat(hidden_sequence, dim = 0)

        return hidden_sequence, (h_t, c_t)

# %% [markdown]
# ### 2.3.2 adjusted classical QLSTM

# %%
class AdjustedQLSTM(QLSTMBase):
    def __init__(self, input_size, hidden_size, *, ctx):
        super().__init__(input_size, hidden_size, ctx = ctx)
        
        # gates names:  qubits  layers  degree
        # input gate:     4       2       3
        # forget gate:    5       2       3
        # candidate:      4       1       3
        # output gate:    3       2       2
        
        # input gates
        self.input_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                        n_qubits = 4, n_layers = 2, degree = 3, ctx = ctx) # 36
        # forget gates
        self.forget_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                         n_qubits = 5, n_layers = 2, degree = 3, ctx = ctx) # 45
        # candidate
        self.candidate_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                       n_qubits = 4, n_layers = 1, degree = 3, ctx = ctx) # 24
        # output gates
        self.output_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                         n_qubits = 3, n_layers = 2, degree = 2, ctx = ctx) # 18
        
    def forward(self, inputs, init_states = None):
        hidden_sequence, (h_t, c_t) = super(AdjustedQLSTM, self).forward(inputs, init_states)

        for t in range(inputs.size()[0]):
            x_t = inputs[t, :, :]
            v_t = torch.cat((h_t[0], x_t), dim = 1)

            # input gates
            i_t = torch.sigmoid(self.input_circuit(v_t))
            # forget gates
            f_t = torch.sigmoid(self.forget_circuit(v_t))
            # candidate for cell state update
            g_t = torch.tanh(self.candidate_circuit(v_t))
            c_t = (f_t * c_t) + (i_t * g_t)

            # output gates
            o_t = torch.sigmoid(self.output_circuit(v_t))
            # update output ht
            h_t = o_t * (torch.tanh(c_t))

            hidden_sequence.append(h_t)

        hidden_sequence = torch.cat(hidden_sequence, dim = 0)

        return hidden_sequence, (h_t, c_t)

# %% [markdown]
# ### 2.3.3 peephole QLSTM

# %%
class PeepholeQLSTM(QLSTMBase):
    def __init__(self, input_size, hidden_size, *, ctx):
        super().__init__(input_size, hidden_size, ctx = ctx)
        
        # gates names:  qubits  layers  degree
        # input gate:     4       2       3
        # forget gate:    5       2       3
        # candidate:      4       1       3
        # output gate:    3       2       2
        
        # input gates
        self.input_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                        n_qubits = 4, n_layers = 2, degree = 3, ctx = ctx) # 36
        # forget gates
        self.forget_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                         n_qubits = 5, n_layers = 2, degree = 3, ctx = ctx) # 45
        # candidate
        self.candidate_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                       n_qubits = 4, n_layers = 1, degree = 2, ctx = ctx) # 24
        # output gates
        self.output_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                         n_qubits = 3, n_layers = 2, degree = 2, ctx = ctx) # 18
        
    def forward(self, inputs, init_states = None):
        hidden_sequence, (h_t, c_t) = super(PeepholeQLSTM, self).forward(inputs, init_states)

        for t in range(inputs.size()[0]):
            x_t = inputs[t, :, :]
            v_t = torch.cat((c_t[0], x_t), dim = 1)
            
            # input gates
            i_t = torch.sigmoid(self.input_circuit(v_t))
            # forget gates
            f_t = torch.sigmoid(self.forget_circuit(v_t))
            # candidate for cell state update
            g_t = torch.tanh(self.candidate_circuit(v_t))
            c_t = (f_t * c_t) + (i_t * g_t)
            
            # output gates
            o_t = torch.sigmoid(self.output_circuit(v_t))
            # update output ht
            h_t = o_t * (torch.tanh(c_t))

            hidden_sequence.append(h_t)

        hidden_sequence = torch.cat(hidden_sequence, dim = 0)

        return hidden_sequence, (h_t, c_t)

# %% [markdown]
# ### 2.3.4 Coupled Input and Forget gates QLSTM

# %%
class CIFGQLSTM(QLSTMBase):
    def __init__(self, input_size, hidden_size, *, ctx):
        super().__init__(input_size, hidden_size, ctx = ctx)
        
        # gates names:  qubits  layers  degree
        # coupled IF:     5       2       3
        # candidate:      4       2       3
        # output gate:    3       2       2
        
        # Coupled Input and Forget gate
        self.coupled_IF_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                         n_qubits = 5, n_layers = 1, degree = 3, ctx = ctx) # 30
        # candidate for cell state update
        self.candidate_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                       n_qubits = 3, n_layers = 1, degree = 2, ctx = ctx) # 24
        # output gates
        self.output_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                         n_qubits = 4, n_layers = 1, degree = 3, ctx = ctx) # 12
        
    def forward(self, inputs, init_states = None):
        hidden_sequence, (h_t, c_t) = super(CIFGQLSTM, self).forward(inputs, init_states)

        for t in range(inputs.size()[0]):
            x_t = inputs[t, :, :]
            v_t = torch.cat((h_t[0], x_t), dim = 1)
            
            # coupled input and forget gate
            f_t = torch.sigmoid(self.coupled_IF_circuit(v_t))
            # candidate for cell state update
            g_t = torch.tanh(self.candidate_circuit(v_t))
            c_t = (f_t * c_t) + ((1 - f_t) * g_t)
            
            # output gates
            o_t = torch.sigmoid(self.output_circuit(v_t))
            # update output ht
            h_t = o_t * (torch.tanh(c_t))

            hidden_sequence.append(h_t)

        hidden_sequence = torch.cat(hidden_sequence, dim = 0)

        return hidden_sequence, (h_t, c_t)

# %% [markdown]
# ### 2.3.5 Recurrent Gate Units - QGRU

# %%
class QGRU(QLSTMBase):
    def __init__(self, input_size, hidden_size, *, ctx):
        super().__init__(input_size, hidden_size, ctx = ctx)
        
        # gates names:  qubits  layers  degree
        # update gate:     5       1       3
        # candidate:       4       1       3
        # reset gate:      3       1       2
        
        # update gates
        self.update_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                         n_qubits = 5, n_layers = 1, degree = 1, ctx = ctx) # 45
        # candidate for hidden state update
        self.candidate_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                       n_qubits = 3, n_layers = 1, degree = 1, ctx = ctx) # 36
        # reset gates
        self.reset_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                         n_qubits = 4, n_layers = 1, degree = 1, ctx = ctx) # 18
        
    def forward(self, inputs, init_states = None):
        hidden_sequence, (h_t, c_t) = super(QGRU, self).forward(inputs, init_states)

        for t in range(inputs.size()[0]):
            x_t = inputs[t, :, :]
            v_t = torch.cat((h_t[0], x_t), dim = 1)
            
            # update gates
            z_t = torch.sigmoid(self.update_circuit(v_t))
            # reset gates
            r_t = torch.sigmoid(self.reset_circuit(v_t))
        
            v_hat_t = torch.cat(((r_t * h_t)[0], x_t), dim = 1)
            # candidate for hidden state update
            g_t = torch.tanh(self.candidate_circuit(v_hat_t))
            h_t = (z_t * g_t) + (1 - z_t) * h_t 

            hidden_sequence.append(h_t)

        hidden_sequence = torch.cat(hidden_sequence, dim = 0)

        return hidden_sequence, (h_t, c_t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 class QGRU(QLSTMBase):
#       2     def __init__(self, input_size, hidden_size, *, ctx):
#       3         super().__init__(input_size, hidden_size, ctx = ctx)
#
# NameError: name 'QLSTMBase' is not defined

# %% [markdown]
# ### - QLSTMs Map

# %%
QLSTMMap = {
    'classical': ('QLSTM', QLSTM),
    'adjusted': ('QLSTM(adjusted)', AdjustedQLSTM),
    'peephole': ('peephole QLSTM', PeepholeQLSTM),
    'CIFG': ('CIFG-QLSTM', CIFGQLSTM),
    'GRU': ('QGRU', QGRU)
}

# %% [markdown]
# ## 2.4 Stacked QLSTM

# %%
from collections import OrderedDict

class StackedQLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, *, num_layers = 1, ctx = None, mode = 'classical'):
        super().__init__()
        
        label, qlstm = QLSTMMap.get(mode)
        self.qlstms = nn.Sequential(OrderedDict([
            (f'{label} {i + 1}', qlstm(input_size if i == 0 else hidden_size , hidden_size, ctx = ctx)) 
                for i in range(num_layers)
        ]))

    def forward(self, inputs, parameters = None):
        outputs = None
        
        for i, qlstm in enumerate(self.qlstms):
            if i != 0:
                inputs = outputs
            
            outputs, parameters = qlstm(inputs, parameters)
        
        return outputs, parameters

# %% [markdown]
# # 3. Quantum Model and Train

# %%
class QModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_output, *, num_layers = 1, ctx = None, mode = 'classical'):
        super(QModel, self).__init__()
        
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.mode = mode
        
        self.qlstm = StackedQLSTM(input_size, hidden_size, 
                                  num_layers = num_layers, ctx = ctx, mode = mode)
        self.predict = nn.Linear(hidden_size, num_output)

    def forward(self, x):
        x = x.unsqueeze(0)
        
        # sequence lenth , batch_size, features length
        # 
        h0 = torch.zeros(1, x.size(1), self.hidden_size)
        c0 = torch.zeros(1, x.size(1), self.hidden_size)
        
        out, _ = self.qlstm(x, (h0, c0))
        out = self.predict(out[0])
        
        return out

# %% [markdown]
# ## 3.1 train QModel

# %%
from torch.utils.data import RandomSampler

def train_model(model, datas, batch_size, *, loss_func, optimizer, epoch = 50, early_stop = False):
    losses = []
    sampler = RandomSampler(datas, num_samples = batch_size)
    
    last_loss = 0.0
    for step in range(epoch):
        train_loss = 0.0
        
        for index in sampler:
            batch_x, batch_y = datas[index][0], datas[index][1]
            b_x = batch_x.unsqueeze(0)
            b_y = batch_y.unsqueeze(0)
            
            output = model(b_x)

            loss = loss_func(output, b_y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        loss = train_loss / batch_size
        if early_stop and loss < 0.0002:
            break
            
        last_loss = loss
        
        print(f'Epoch {step + 1}/{epoch}: Loss: {loss}')
        losses.append(loss)
    
    return losses

# %% [markdown]
# ## 3.2 Evaluate Model

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

# %%
def MAE_naive(actuals, predicteds):
    n = len(actuals)
    err = 0.0
    
    for i in range(1, n):
        err += np.abs(actuals[i] - actuals[i - 1])
    return err / (n - 1)

def calculate_accuarcy(model, X_test, y_test, scaler=train_scaler):
    n = len(X_test)
    
    actuals = []
    predicteds = []
    
    for i in range(0, n, predict_size):
        actual = scaler.inverse_transform(y_test[i:i+1].data)
        actuals.append(np.array(actual[0]))
        predicted = scaler.inverse_transform(model(X_test[i:i+1]).data)
        predicteds.append(np.array(predicted[0]))
    
    actuals = np.array(actuals)
    predicteds = np.array(predicteds)
    
    mae = mean_absolute_error(actuals, predicteds)
    mase = mae / MAE_naive(actuals.flatten(), predicteds.flatten())
    mape = mean_absolute_percentage_error(actuals, predicteds)
    mse = mean_squared_error(actuals, predicteds)
    rmse = mse ** 0.5
    
    return np.array([(1 - mase) * 100, rmse, mse, mae, mape])

# %%
def calculate_accuarcies(model, X_test, y_test, scaler=test_scaler):
    n = len(X_test)
    
    actuals = []
    predicteds = []
    
    for i in range(0, n, predict_size):
        actual = scaler.inverse_transform(y_test[i:i+1].data)
        actuals.append(np.array(actual[0]))
        predicted = scaler.inverse_transform(model(X_test[i:i+1]).data)
        predicteds.append(np.array(predicted[0]))
    
    accuarcies = []
    for i in range(predict_size):
        a = [row[i] for row in actuals]
        p = [row[i] for row in predicteds]
    
        mae = mean_absolute_error(a, p)
        mase = mae / MAE_naive(a, p)
        mape = mean_absolute_percentage_error(a, p)
        mse = mean_squared_error(a, p)
        rmse = mse ** 0.5
        
        accuarcies.append([rmse, mse, mae, mape, mase])
    
    return np.array(accuarcies)

# %% [markdown]
# ## 3.3 Train Model

# %%
features_size = 4
window_size = features_size * 3 # 
predict_size = features_size # features

input_size = window_size
num_output = predict_size

hidden_size = 32
num_layers = 2

# %%
# learning rate:
# classical: 0.0035
# adjusted: 0.0028
# peephole: 0.0027 -> 0.003
# CIFG: 0.004 -> 0.0035
# CIFG2: 0.0028
# GRU: 0.0035 -> 0.0028
# GRU3: 0.0012

# %%
times = []
accuarcies = []
models = []
mode = 'classical'
for i in range(10):
    print(f'epoch: {i + 1}')
    qmodel = QModel(input_size, hidden_size, num_output, 
                    num_layers = num_layers, ctx = ctx, mode=mode)
    optimizer = torch.optim.Adam(qmodel.parameters(), lr = 0.0035)
    loss_func = nn.MSELoss()

    start = time.time()
    losses = train_model(qmodel, train_data, batch_size=20,          
                   loss_func = loss_func, optimizer = optimizer, epoch = 100)
    end = time.time()

    print(f'time costs: {end - start}')
    times.append(end - start)
    
    accuarcy = calculate_accuarcy(qmodel, X_test, y_test)[0]
    print(f'accuarcy: {accuarcy}')
    accuarcies.append(accuarcy)
    
    with open(f'loss/{mode}/loss_{mode}_{i+1}.pkl', 'wb') as pkl_file:
        pickle.dump(losses, pkl_file)
        
    models.append(qmodel)
    torch.save(qmodel.state_dict(), f"model/{mode}/model_{mode}_{i+1}.pt")

print(f"mean times:{np.mean(times)}")
print(f"mean accuarcy:{np.mean(accuarcies)}")
# Out:
# epoch: 1
# Epoch 1/100: Loss: 1.0023835718631744
# Epoch 89/100: Loss: 0.0007321652454265859
# Epoch 90/100: Loss: 0.0007907551385869738
# Epoch 91/100: Loss: 0.0006694193780276692
# Epoch 92/100: Loss: 0.00045432041679305257
# Epoch 93/100: Loss: 0.0005821218375785975
# Epoch 94/100: Loss: 0.0005828143752296455
# Epoch 95/100: Loss: 0.0006663654812655295
# Epoch 96/100: Loss: 0.0004948693084315892
# Epoch 97/100: Loss: 0.0008341091765032615
# Epoch 98/100: Loss: 0.00048546886200711014
# Epoch 99/100: Loss: 0.0005652652762364596
# Epoch 100/100: Loss: 0.000661425209909794
# time costs: 674.4980578422546
# accuarcy: 98.224821479975
# mean times:741.617260169983
# mean accuarcy:98.55977887098507

# %%
mode = 'classical'
qmodel = QModel(input_size, hidden_size, num_output, 
                    num_layers = num_layers, ctx = ctx, mode=mode)

# %%
qmodel.load_state_dict(torch.load(f"./model/{mode}/model_{mode}_2.pt"))
# Out:
# <All keys matched successfully>

# %%
accuarcies
# Out:
# [98.73553256546558,
#  98.46611637952071,
#  98.70623463571623,
#  98.23995808815762,
#  98.45591833853551,
#  98.2114917687926,
#  98.14373994193355,
#  98.6773874128265,
#  97.86947998075797,
#  98.74451836560287]

# %%
# classical: 
# [98.72359271783994,
#  98.56474521506847,
#  98.41702256725704,
#  98.60767155216824,
#  97.70674038758196,
#  98.84762115133579,
#  98.77655405058134,
#  98.53560400010319,
#  97.87521780263079,
#  98.17159161746723]
# mean times:504.23733682632445
# mean accuarcy:98.4226361062034

# %%
# adjusted
# [98.23299788316724,
#  98.63113456731728,
#  98.3732659516424,
#  98.79958084225468,
#  98.12992737994425,
#  98.9788383754037,
#  98.91326150811646,
#  98.70481749315803,
#  98.82973044959333,
#  98.79680598415123]
# mean times:445.88511500358584
# mean accuarcy:98.63903604347485

# %%
# peephole
# [98.90306999830709,
#  98.59789407544017,
#  98.56799411839711,
#  98.71180994722229,
#  98.60452917053428,
#  98.63728867920504,
#  98.83119724469138,
#  98.019140782863,
#  98.42381131216362,
#  98.28401949012051]
# mean times:547.0948097467423
# mean accuarcy:98.55807548189445

# %%
# peephole2
# [98.73553256546558,
#  98.46611637952071,
#  98.70623463571623,
#  98.63995808815762,
#  98.55591833853551,
#  98.5814917687926,
#  98.66683994193355,
#  98.6773874128265,
#  98.56947998075797,
#  98.74451836560287]
# mean times:544.8170275688171
# mean accuarcy:98.63503774773091

# %%
# CIFG
# [98.76377276794422,
#  98.79708626744475,
#  98.74303466857964,
#  98.8535437185511,
#  98.36660277026313,
#  98.18934489702863,
#  98.63765910609955,
#  98.71232920913755,
#  98.95224558958566,
#  98.63444040110015]
# mean times:417.6877571821213
# mean accuarcy:98.66500593957345

# %%
# CIFG2
# [98.68462175936716,
#  98.88357649474516,
#  98.80781666613295,
#  98.88239103060363,
#  98.60562265766453,
#  98.80524791901037,
#  98.73071247410631,
#  98.91238862092374,
#  98.75715997469798,
#  97.56271448560352]
# mean times:366.5394344806671
# mean accuarcy:98.62675520828552

# %%
# GRU
# [98.64063606285741,
#  98.87254824768983,
#  98.74386202701247,
#  98.46609956675834,
#  98.4246390272477,
#  98.9113277618093,
#  98.15781233549679,
#  98.11105537460467,
#  98.60968159955014,
#  98.62328119059485]
# mean times:396.3512500524521
# mean accuarcy:98.55609431936215

# %%
# GRU2
# [98.94613727394623,
#  98.53658589997661,
#  98.46087527809024,
#  98.73615447049326,
#  98.90670921183688,
#  98.78959937773517,
#  98.8858469866953,
#  98.72970477274473,
#  98.89681663149368,
#  99.02955717988124]
# mean times:476.27589938640597
# mean accuarcy:98.79179870828935

# %%
# GRU3
# [98.95361895877677,
#  98.66578625570767,
#  99.00887237201371,
#  99.00502900908486,
#  98.85608262956835,
#  98.98795639841568,
#  98.67064187287409,
#  98.72733454661879,
#  98.55078955234166,
#  98.80464700625178]
# mean times:399.03404235839844
# mean accuarcy:98.82307586016535

# %%
qmodel = QModel(input_size, hidden_size, num_output, 
                num_layers = num_layers, ctx = ctx, mode='GRU')
optimizer = torch.optim.Adam(qmodel.parameters(), lr = 0.0008)
loss_func = nn.MSELoss()

start = time.time()
losses = train_model(qmodel, train_data, batch_size=20,          
               loss_func = loss_func, optimizer = optimizer, epoch = 200, early_stop=True)
end = time.time()

print(f'time costs: {end - start}')
# Out:
# Epoch 1/200: Loss: 1.0047239392995835
# Epoch 2/200: Loss: 1.016366770863533
# Epoch 3/200: Loss: 0.9172667324542999
# Epoch 4/200: Loss: 0.9745915830135345
# Epoch 5/200: Loss: 0.9637506186962128
# Epoch 6/200: Loss: 0.9255561977624893
# Epoch 7/200: Loss: 0.8966167211532593
# Epoch 8/200: Loss: 0.8618280082941056
# Epoch 9/200: Loss: 0.8465825736522674
# Epoch 10/200: Loss: 0.8572704374790192
# Epoch 11/200: Loss: 0.7886811584234238
# Epoch 12/200: Loss: 0.761615177989006
# Epoch 13/200: Loss: 0.7448442697525024
# Epoch 14/200: Loss: 0.7661686301231384
# Epoch 15/200: Loss: 0.7275607407093048
# Epoch 16/200: Loss: 0.6426466703414917
# Epoch 17/200: Loss: 0.6621754571795464
# Epoch 18/200: Loss: 0.6676389157772065
# Epoch 19/200: Loss: 0.5918421611189842
# Epoch 20/200: Loss: 0.6010327577590943
# Epoch 21/200: Loss: 0.5484421625733376
# Epoch 22/200: Loss: 0.5824389085173607
# Epoch 23/200: Loss: 0.5228617407381535
# Epoch 24/200: Loss: 0.5260711550712586
# Epoch 25/200: Loss: 0.5047428265213967
# Epoch 26/200: Loss: 0.5057485796511173
# Epoch 27/200: Loss: 0.5385906666517257
# Epoch 28/200: Loss: 0.48116848766803744
# Epoch 29/200: Loss: 0.4318291716277599
# Epoch 30/200: Loss: 0.4081715114414692
# Epoch 31/200: Loss: 0.4327189393341541
# Epoch 32/200: Loss: 0.42755063250660896
# Epoch 33/200: Loss: 0.3677582949399948
# Epoch 34/200: Loss: 0.343965283036232
# Epoch 35/200: Loss: 0.22552804090082645
# Epoch 36/200: Loss: 0.34051920622587206
# Epoch 37/200: Loss: 0.35846567526459694
# Epoch 38/200: Loss: 0.3080854248255491
# Epoch 39/200: Loss: 0.360355231910944
# Epoch 40/200: Loss: 0.1789547735825181
# Epoch 41/200: Loss: 0.26155474297702314
# Epoch 140/200: Loss: 0.00029769699685857633
# Epoch 141/200: Loss: 0.0003477027148619527
# Epoch 142/200: Loss: 0.00037875217549299123
# Epoch 143/200: Loss: 0.0003178427130478667
# Epoch 144/200: Loss: 0.0004894300682281028
# Epoch 145/200: Loss: 0.0003041574750568543
# Epoch 146/200: Loss: 0.0002918981421316857
# Epoch 147/200: Loss: 0.0003706391406012699
# Epoch 148/200: Loss: 0.0003761657564609777
# Epoch 149/200: Loss: 0.0003273768725193804
# Epoch 150/200: Loss: 0.00042329432453698247
# Epoch 151/200: Loss: 0.00033941419542316
# Epoch 152/200: Loss: 0.00037841536395717413
# Epoch 153/200: Loss: 0.0003903600721969269
# Epoch 154/200: Loss: 0.0002888738879846642
# Epoch 155/200: Loss: 0.00044663652734016067
# Epoch 156/200: Loss: 0.0004027844759548316
# Epoch 157/200: Loss: 0.00035575307674662326
# Epoch 158/200: Loss: 0.00028399794773577015
# Epoch 159/200: Loss: 0.0004564120989016374
# Epoch 160/200: Loss: 0.0005767988975094341
# Epoch 161/200: Loss: 0.0004179091654123113
# Epoch 162/200: Loss: 0.000404579022051621
# Epoch 163/200: Loss: 0.0004246758107910864
# Epoch 164/200: Loss: 0.00031686159272794614
# Epoch 165/200: Loss: 0.00033122027070930926
# Epoch 166/200: Loss: 0.0004355101535566064
# Epoch 167/200: Loss: 0.00038822524124952905
# Epoch 168/200: Loss: 0.0003401769186893944
# Epoch 169/200: Loss: 0.0002724935664446093
# Epoch 170/200: Loss: 0.00043021190012950685
# Epoch 171/200: Loss: 0.00033964041326726144
# Epoch 172/200: Loss: 0.00044668001883110266
# Epoch 173/200: Loss: 0.00038187194313650253
# Epoch 174/200: Loss: 0.0003358860861226276
# Epoch 175/200: Loss: 0.0005068622883300123
# Epoch 176/200: Loss: 0.00033528413973726856
# Epoch 177/200: Loss: 0.0004829207038710592
# Epoch 178/200: Loss: 0.0002513529669158743
# Epoch 179/200: Loss: 0.00030414573820962686
# Epoch 180/200: Loss: 0.0003476519921605359
# Epoch 181/200: Loss: 0.0003271346733527025
# Epoch 182/200: Loss: 0.0003452138880675193
# Epoch 183/200: Loss: 0.00038697313029842915
# Epoch 184/200: Loss: 0.00030886254771758106
# Epoch 185/200: Loss: 0.0003644685471044795
# Epoch 186/200: Loss: 0.00030823314145891347
# Epoch 187/200: Loss: 0.00029585403954115466
# Epoch 188/200: Loss: 0.00032804522675178305
# Epoch 189/200: Loss: 0.0003461767395492643
# Epoch 190/200: Loss: 0.00027607877054833805
# Epoch 191/200: Loss: 0.0005272369606245774
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [347], line 9
#       6 loss_func = nn.MSELoss()
#       8 start = time.time()
# ----> 9 losses = train_model(qmodel, train_data, batch_size=20,
#      10                loss_func = loss_func, optimizer = optimizer, epoch = 200, early_stop=True)
#      11 end = time.time()
#      13 print(f'time costs: {end - start}')
#
# Cell In [284], line 16, in train_model(model, datas, batch_size, loss_func, optimizer, epoch, early_stop)
#      13 b_x = batch_x.unsqueeze(0)
#      14 b_y = batch_y.unsqueeze(0)
# ---> 16 output = model(b_x)
#      18 loss = loss_func(output, b_y)
#      19 optimizer.zero_grad()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In [43], line 21, in QModel.forward(self, x)
#      18 h0 = torch.zeros(1, x.size(1), self.hidden_size)
#      19 c0 = torch.zeros(1, x.size(1), self.hidden_size)
# ---> 21 out, _ = self.qlstm(x, (h0, c0))
#      22 out = self.predict(out[0])
#      24 return out
#
# File ~\AppData\Roaming\Python\Python38\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In [42], line 20, in StackedQLSTM.forward(self, inputs, parameters)
#      17     if i != 0:
#      18         inputs = outputs
# ---> 20     outputs, parameters = qlstm(inputs, parameters)
#      22 return outputs, parameters
#
# File ~\AppData\Roaming\Python\Python38\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In [40], line 34, in QGRU.forward(self, inputs, init_states)
#      32 v_hat_t = torch.cat(((r_t * h_t)[0], x_t), dim = 1)
#      33 # candidate for hidden state update
# ---> 34 g_t = torch.tanh(self.candidate_circuit(v_hat_t))
#      35 h_t = (z_t * g_t) + (1 - z_t) * h_t
#      37 hidden_sequence.append(h_t)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In [32], line 5, in forward(self, inputs)
#       2 y_t = self.qin(Parameter(inputs))
#       3 self.data = y_t[0]
# ----> 5 return self.qout(self.measure())
#
# Cell In [31], line 3, in measure(self)
#       1 def measure(self):
#       2     HamiZ = [ PauliOperator({f'Z{i}': 1}) for i in range(len(self.qubits)) ]
# ----> 3     res = [ eval(qop(self.circuit, Hami, self.machine, self.qubits))[0,0] for Hami in HamiZ ]
#       5     return Parameter(Tensor(res[:self.n_qubits]))
#
# Cell In [31], line 3, in <listcomp>(.0)
#       1 def measure(self):
#       2     HamiZ = [ PauliOperator({f'Z{i}': 1}) for i in range(len(self.qubits)) ]
# ----> 3     res = [ eval(qop(self.circuit, Hami, self.machine, self.qubits))[0,0] for Hami in HamiZ ]
#       5     return Parameter(Tensor(res[:self.n_qubits]))
#
# Cell In [33], line 43, in QuantumLayer.circuit(self)
#      40 [ vqc.insert(identity(q[i])) for i in range(len(q)) ]
#      42 [ vqc.insert( h(q[i]) ) for i in range(n) ]
# ---> 43 [ vqc.insert( ry(q[i], var(x[i] * torch.pi/2)) ) for i in range(n) ]
#      44 [ vqc.insert( u[degree](q[i], *[ var(p[0][d][i]) for d in range(degree) ]) )
#      45          for i in range(n) ]
#      47 for layer in range(self.n_layers):
#
# Cell In [33], line 43, in <listcomp>(.0)
#      40 [ vqc.insert(identity(q[i])) for i in range(len(q)) ]
#      42 [ vqc.insert( h(q[i]) ) for i in range(n) ]
# ---> 43 [ vqc.insert( ry(q[i], var(x[i] * torch.pi/2)) ) for i in range(n) ]
#      44 [ vqc.insert( u[degree](q[i], *[ var(p[0][d][i]) for d in range(degree) ]) )
#      45          for i in range(n) ]
#      47 for layer in range(self.n_layers):
#
# KeyboardInterrupt:

# %%
calculate_accuarcy(qmodel, X_test, y_test)
# Out:
# array([ 97.89852066,  16.23396277, 263.54154707,  10.81832791,
#          0.29530446])

# %%
calculate_accuarcies(qmodel, X_test, y_test)

# %%
mode = "CIFG"

# %%
with open(f'loss/{mode}2/loss_{mode}2_1.pkl', 'wb') as pkl_file:
    pickle.dump(losses, pkl_file)

# %%
torch.save(qmodel.state_dict(), f"model/{mode}2/model_{mode}2_1.pt")

# %% [markdown]
# ### - describe trained model

# %%
qmodel = QModel(input_size, hidden_size, num_output, 
                num_layers = num_layers, ctx = ctx, mode='GRU')

# %%
qmodel
# Out:
# QModel(
#   (qlstm): StackedQLSTM(
#     (qlstms): Sequential(
#       (QLSTM 1): QLSTM(
#         (input_circuit): QuantumLayer(
#           (qin): Linear(in_features=44, out_features=5, bias=True)
#           (qout): Linear(in_features=5, out_features=32, bias=True)
#         )
#         (forget_circuit): QuantumLayer(
#           (qin): Linear(in_features=44, out_features=5, bias=True)
#           (qout): Linear(in_features=5, out_features=32, bias=True)
#         )
#         (candidate_circuit): QuantumLayer(
#           (qin): Linear(in_features=44, out_features=5, bias=True)
#           (qout): Linear(in_features=5, out_features=32, bias=True)
#         )
#         (output_circuit): QuantumLayer(
#           (qin): Linear(in_features=44, out_features=5, bias=True)
#           (qout): Linear(in_features=5, out_features=32, bias=True)
#         )
#       )
#       (QLSTM 2): QLSTM(
#         (input_circuit): QuantumLayer(
#           (qin): Linear(in_features=64, out_features=5, bias=True)
#           (qout): Linear(in_features=5, out_features=32, bias=True)
#         )
#         (forget_circuit): QuantumLayer(
#           (qin): Linear(in_features=64, out_features=5, bias=True)
#           (qout): Linear(in_features=5, out_features=32, bias=True)
#         )
#         (candidate_circuit): QuantumLayer(
#           (qin): Linear(in_features=64, out_features=5, bias=True)
#           (qout): Linear(in_features=5, out_features=32, bias=True)
#         )
#         (output_circuit): QuantumLayer(
#           (qin): Linear(in_features=64, out_features=5, bias=True)
#           (qout): Linear(in_features=5, out_features=32, bias=True)
#         )
#       )
#     )
#   )
#   (predict): Linear(in_features=32, out_features=4, bias=True)
# )

# %%
trainable = 0
for p in qmodel.parameters():
    if p.requires_grad:
        trainable += p.numel()
print(f'total parameters: {trainable}')

qlstm = QLSTMMap.get(qmodel.mode)[1]
print(f'quantum paramers: {qlstm(1, 1, ctx = ctx).qparameters_size}')
# Out:
# total parameters: 2460
# quantum paramers: 24

# %% [markdown]
# ### - Save the Model

# %%
# save the model
torch.save(qmodel.state_dict(), "model/qmodel_GRU.pt")

# %% [markdown]
# ## 3.4 Statistics

# %%
# np.array([(1 - mase) * 100, rmse, mse, mae, mape])

# %%
mode = 'adjusted'

# %%
def statistic(mode, epoch=10): 
    accuarcy = 0.0
    rmse = 0.0
    mse = 0.0
    mae = 0.0
    mape = 0.0
    
    for i in range(epoch):
        qmodel = QModel(input_size, hidden_size, num_output, 
                    num_layers = num_layers, ctx = ctx, mode=mode)
        qmodel.load_state_dict(torch.load(f"model/{mode}/model_{mode}_{i+1}.pt"))
        
        results = calculate_accuarcy(qmodel, X_test, y_test)
        accuarcy += results[0]
        rmse += results[1]
        mse += results[2]
        mae += results[3]
        mape += results[4]

    accuarcy /= epoch
    rmse /= epoch
    mse /= epoch
    mae /= epoch
    mape /= epoch
    
    print(f'mean accuarcy: {accuarcy}%')
    print(f'mean RMSE: {rmse}')
    print(f'mean MSE: {mse}')
    print(f'mean MAE: {mae}')
    print(f'meab MAPE: {mape}')
    
    return [accuarcy, rmse, mse, mae, mape]

# %%
# classical
statistic_results = statistic(mode)
# Out:
# mean accuarcy: 98.54994615686289%
# mean RMSE: 9.653941815807855
# mean MSE: 96.08898386543845
# mean MAE: 7.467789769363319
# meab MAPE: 0.2910629472268616

# %%
# peephole
statistic_results = statistic(mode)
# Out:
# mean accuarcy: 98.55807548189445%
# mean RMSE: 9.632796836784154
# mean MSE: 96.15784603556865
# mean MAE: 7.425923675500803
# meab MAPE: 0.27546597701157033

# %%
# CIFG
statistic_results = statistic(mode)
# Out:
# mean accuarcy: 98.66323007886952%
# mean RMSE: 8.936394244765822
# mean MSE: 85.08853885502472
# mean MAE: 6.8843765962606795
# meab MAPE: 0.2903496047479904

# %%
# GRU
statistic_results = statistic(mode)
# Out:
# mean accuarcy: 98.82307586016532%
# mean RMSE: 7.882642366226747
# mean MSE: 63.0652681275086
# mean MAE: 6.061169447169975
# meab MAPE: 0.23865214187185257

# %%
qmodel = QModel(input_size, hidden_size, num_output, 
                num_layers = num_layers, ctx = ctx, mode='GRU')

# %%
qmodel.load_state_dict(torch.load(f"./model/CIFG2/model_CIFG2_1.pt"))
# Out:
# <All keys matched successfully>

# %%
qmodel.load_state_dict(torch.load(f"./model/GRU3/model_GRU3_4.pt"))
# Out:
# <All keys matched successfully>

# %%
calculate_accuarcy(qmodel, X_test, y_test)
# Out:
# array([99.00231146,  6.99726309, 48.96169077,  5.13605894,  0.17694298])

# %%
calculate_accuarcies(qmodel, X_test, y_test)
# Out:
# array([[  4.73780477,  22.44679405,   3.86358781,   0.18066322,
#           2.9562802 ],
#        [ 11.65121763, 135.75087228,   9.69747171,   0.21705672,
#           1.65079302],
#        [  4.51153598,  20.35395689,   3.44812479,   0.49403132,
#           1.11807786],
#        [  4.30237501,  18.51043071,   3.62028622,   0.00358361,
#           2.42453491]])

# %%
results = []

for i in range(0, len(X_test), features_size):
    input_data = X_test[i:i+1]
    result = qmodel(input_data)
    result = train_scaler.inverse_transform(result.data)
    
    results.append(result[0])

# %%
test1 = pd.DataFrame(test, columns=('meantemp',))
test2 = pd.DataFrame(test, columns=('humidity',))
test3 = pd.DataFrame(test, columns=('wind_speed',))
test4 = pd.DataFrame(test, columns=('meanpressure',))

# %%
results = pd.DataFrame(results)
results.columns = ('meantemp', 'humidity', 'wind_speed', 'meanpressure')
results
# Out:
#       meantemp   humidity  wind_speed  meanpressure
# 0    17.062270  67.692835    4.195018   1013.619007
# 1    19.213526  71.658590   -4.394649   1017.484953
# 2    17.397308  65.875632    5.989264   1013.243156
# 3    23.023481  66.304116    5.470593   1008.499735
# 4    24.019680  63.049363   14.097361   1001.231936
# ..         ...        ...         ...           ...
# 106  33.187116  55.648947    8.164790   1007.525079
# 107  36.050094  50.632516   15.869078   1001.005951
# 108  39.653435  48.289673   21.064595    994.058895
# 109  41.032986  53.145303   13.516966    996.546199
# 110  34.660491  59.192256    3.712413   1007.401731
#
# [111 rows x 4 columns]

# %%
result1 = pd.DataFrame(results, columns=('meantemp', 'humidity', 'wind_speed'))
result2 = pd.DataFrame(results, columns=('meanpressure',))

# %%
result1
# Out:
#       meantemp   humidity  wind_speed
# 0    17.062270  67.692835    4.195018
# 1    19.213526  71.658590   -4.394649
# 2    17.397308  65.875632    5.989264
# 3    23.023481  66.304116    5.470593
# 4    24.019680  63.049363   14.097361
# ..         ...        ...         ...
# 106  33.187116  55.648947    8.164790
# 107  36.050094  50.632516   15.869078
# 108  39.653435  48.289673   21.064595
# 109  41.032986  53.145303   13.516966
# 110  34.660491  59.192256    3.712413
#
# [111 rows x 3 columns]

# %%
plt.figure(figsize=(15, 4))
plt.subplot(1,2,1)
plt.plot(test1, label="meantemp")
plt.plot(test2, label="humidity")
plt.plot(test3, label="wind_speed")

# plt.subplot(1,2,2)
plt.ylim(0, 100)
plt.plot(result1.index + 3, result1.values, color="#FF6666", linestyle="--")
plt.legend()

# plt.subplot(1,2,1)
plt.subplot(1,2,2)
plt.plot(test4, label="meanpressure", color="#9966CC")
plt.ylim(980, 1050)
plt.plot(result2.index + 3, result2.values, color="#FF6666", linestyle='--')

plt.legend()

# %%
plt.figure(figsize=(15, 4))
plt.subplot(1,2,1)
plt.plot(test1, label="meantemp")
plt.plot(test2, label="humidity")
plt.plot(test3, label="wind_speed")

# plt.subplot(1,2,2)
plt.ylim(0, 100)
plt.plot(result1.index + 3, result1.values, color="#FF6666", linestyle="--")
plt.legend()

# plt.subplot(1,2,1)
plt.subplot(1,2,2)
plt.plot(test4, label="meanpressure", color="#9966CC")
plt.ylim(980, 1050)
plt.plot(result2.index + 3, result2.values, color="#FF6666", linestyle='--')

plt.legend()

# %%
plt.figure(figsize=(15, 4))
plt.subplot(1,2,1)
plt.plot(test1, label="meantemp")
plt.plot(test2, label="humidity")
plt.plot(test3, label="wind_speed")

# plt.subplot(1,2,2)
plt.ylim(0, 100)
plt.plot(result1, color="#FF6666", linestyle="--")
plt.legend()

# plt.subplot(1,2,1)
plt.subplot(1,2,2)
plt.plot(test4, label="meanpressure", color="#9966CC")
plt.ylim(980, 1050)
plt.plot(result2, color="#FF6666", linestyle='--')

plt.legend()

# %%
plt.figure(figsize=(15, 4))
plt.subplot(1,2,1)
plt.plot(test2)
plt.subplot(1,2,2)
plt.ylim(1000, 1030)
plt.plot(result2)

# %%
results = []

for i in range(0, len(X_train), features_size):
    input_data = X_train[i:i+1]
    result = qmodel(input_data)
    result = train_scaler.inverse_transform(result.data)
    
    results.append(result[0])

# %%
t1 = pd.DataFrame(train, columns=('meantemp',))
t2 = pd.DataFrame(train, columns=('humidity',))
t3 = pd.DataFrame(train, columns=('wind_speed',))
t4 = pd.DataFrame(train, columns=('meanpressure',))
results = pd.DataFrame(results)
results.columns = ('meantemp', 'humidity', 'wind_speed', 'meanpressure')
result1 = pd.DataFrame(results, columns=('meantemp', 'humidity', 'wind_speed'))
result2 = pd.DataFrame(results, columns=('meanpressure',))

# %%
plt.figure(figsize=(15, 4))
plt.subplot(1,2,1)
plt.plot(t1, label="meantemp")
plt.plot(t2, label="humidity")
plt.plot(t3, label="wind_speed")

# plt.subplot(1,2,2)
plt.ylim(0, 100)
plt.plot(result1, color="#FF6666", linestyle="--")
plt.legend()

# plt.subplot(1,2,1)
plt.subplot(1,2,2)
plt.plot(t4, label="meanpressure", color="#9966CC")
plt.ylim(980, 1050)
plt.plot(result2, color="#FF6666", linestyle='--')

plt.legend()
