# %%
import math
import time
import pickle
import pandas as pd
import numpy as np

# %%
import torch
import sklearn

# %%
from pyqpanda import *

# %%
# %matplotlib inline

# %% [markdown]
# # 1. Prepare Dadaset

# %%
# https://www.kaggle.com/datasets/sumanthvrao/daily-climate-time-series-data

# %%
train_path = './data/DailyDelhiClimateTrain.csv'
test_path = './data/DailyDelhiClimateTest.csv'

# %%
cols = [1,2,3,4]

train = pd.read_csv(train_path, usecols=cols, engine="python")
test = pd.read_csv(test_path, usecols=cols, engine="python")

# %% [markdown]
# ## 1.1 Outlier Detection

# %% [markdown]
# ### 1.1.1 outlier detection for train

# %%
plt.scatter(range(len(train)), train["meanpressure"])

# %% [markdown]
# ### - remove outliers

# %%
for i in range(len(train)):
    mp = train.iloc[i][3]
    if mp > 1200 or mp < 950:
        print("unnormal!")
        train.iloc[i][3] = train.iloc[i + 1][3]
# Out:
# unnormal!
# unnormal!
# unnormal!
# unnormal!
# unnormal!
# unnormal!
# unnormal!
# unnormal!
# unnormal!

# %%
plt.plot(train)
# Out:
# [<matplotlib.lines.Line2D at 0x1b5ac4c9190>,
#  <matplotlib.lines.Line2D at 0x1b5ac4c92b0>,
#  <matplotlib.lines.Line2D at 0x1b5ac4c9370>,
#  <matplotlib.lines.Line2D at 0x1b5ac4c9430>]

# %%
train.describe().transpose()
# Out:
#                count         mean        std         min          25%  \
# meantemp      1462.0    25.495521   7.348103    6.000000    18.857143
# humidity      1462.0    60.771702  16.769652   13.428571    50.375000
# wind_speed    1462.0     6.802209   4.561602    0.000000     3.475000
# meanpressure  1462.0  1008.247674   7.437992  991.375000  1001.625000
#
#                       50%          75%          max
# meantemp        27.714286    31.305804    38.714286
# humidity        62.625000    72.218750   100.000000
# wind_speed       6.221667     9.238235    42.220000
# meanpressure  1008.563492  1014.875000  1023.000000

# %%
train[0:1]
# Out:
#    meantemp  humidity  wind_speed  meanpressure
# 0      10.0      84.5         0.0   1015.666667

# %% [markdown]
# ### 1.1.2 outlier detection for test

# %%
plt.scatter(range(len(test)), test["meanpressure"])

# %% [markdown]
# ### - remove outliers

# %%
test.iloc[0][3] = test.iloc[1][3]

# %%
plt.plot(test)
# Out:
# [<matplotlib.lines.Line2D at 0x1b5ac5f13a0>,
#  <matplotlib.lines.Line2D at 0x1b5ac5f14c0>,
#  <matplotlib.lines.Line2D at 0x1b5ac5f1580>,
#  <matplotlib.lines.Line2D at 0x1b5ac5f1640>]

# %% [markdown]
# ## 1.2 Transfer data to LSTM representation

# %%
from sklearn.preprocessing import StandardScaler

# %%
def data_process(data, window_size, predict_size):
    scaler = StandardScaler()
    data = scaler.fit_transform(np.array(data).reshape(-1, 1))
    
    data_in = []
    data_out = []
    
    for i in range(data.shape[0] - window_size - predict_size):
        data_in.append(data[i:i + window_size].reshape(1, window_size)[0])
        data_out.append(data[i + window_size:i + window_size + predict_size].reshape(1, predict_size)[0])
        
    data_in = np.array(data_in).reshape(-1, window_size)
    data_out = np.array(data_out).reshape(-1, predict_size)
    
    data_process = {'datain': data_in, 'dataout': data_out}
    
    return data_process, scaler

# %% [markdown]
# ## 1.3 prepare train/test dataset

# %%
features_size = 4
window_size = features_size * 3 # features num * time steps
predict_size = features_size # features

# %%
train_processed, train_scaler = data_process(train, window_size, predict_size)
X_train, y_train = train_processed['datain'], train_processed['dataout']

test_processed, test_scaler = data_process(test, window_size, predict_size)
X_test, y_test = test_processed['datain'], test_processed['dataout']

# %%
X_train = torch.from_numpy(X_train.astype(np.float32))
X_test = torch.from_numpy(X_test.astype(np.float32))

y_train = torch.from_numpy(y_train.astype(np.float32))
y_test = torch.from_numpy(y_test.astype(np.float32))

# %% [markdown]
# ### - data loader

# %%
import torch.utils.data as Data

train_data = Data.TensorDataset(X_train, y_train)
test_data = Data.TensorDataset(X_test, y_test)

# %%
print(f'size of train_data: {len(train_data)}')
print(f'size of test_data: {len(test_data)}')
# Out:
# size of train_data: 5832
# size of test_data: 440

# %%
train_data[0]
# Out:
# (tensor([-0.6262, -0.4504, -0.6498,  1.7473, -0.6323, -0.4327, -0.6428,  1.7523,
#          -0.6329, -0.4445, -0.6389,  1.7543]),
#  tensor([-0.6293, -0.4814, -0.6469,  1.7508]))

# %%
test_data[0]
# Out:
# (tensor([-0.6067, -0.4426, -0.6376,  1.7437, -0.6006, -0.4629, -0.6372,  1.7437,
#          -0.6039, -0.4520, -0.6346,  1.7438]),
#  tensor([-0.6001, -0.4797, -0.6333,  1.7377]))

# %% [markdown]
# # 2. Quantum Enhanced LSTM

# %% [markdown]
# ## 2.1 initiate quantum environment

# %%
class InitQMachine:
    def __init__(self, qubitsCount, cbitsCount = 0, machineType = QMachineType.CPU):
        self.machine = init_quantum_machine(machineType)
        
        self.qubits = self.machine.qAlloc_many(qubitsCount)
        self.cbits = self.machine.cAlloc_many(cbitsCount)
        
        print(f'Init Quantum Machine with qubits:[{qubitsCount}] / cbits:[{cbitsCount}] Successfully')
    
    def __del__(self):
        destroy_quantum_machine(self.machine)

# %%
# maximum qubits size
ctx = InitQMachine(5)
# Out:
# Init Quantum Machine with qubits:[5] / cbits:[0] Successfully

# %% [markdown]
# ## 2.2 Quantum Layer

# %% [markdown]
# ### - Tool Functions

# %%
def draw(prog, filename=''):
    dir_path = './images/'
    
    if filename != '':
        draw_qprog(prog, 'pic', filename=f'{dir_path}{filename}')

# %% [markdown]
# ### 2.2.1 Quantum Layer Base

# %%
import torch.nn as nn
from torch import Tensor
from torch.nn import Parameter

# %%
class QuantumLayerBase(nn.Module):
    def __init__(self, input_size, output_size, *, n_qubits, n_layers = 1, ctx = None):
        super(QuantumLayerBase, self).__init__()
        
        self.data = None # need to input during forward
    
        self.input_size = input_size
        self.output_size = output_size # hidden size, not n_qubits
        
        # quantum infos
        self.n_qubits = n_qubits
        self.n_layers = n_layers
        
        self.ctx = ctx
        self.qubits = ctx.qubits
        self.machine = ctx.machine
        
        # convert quantum input/output to match classical computation
        self.qin = nn.Linear(self.input_size, self.n_qubits)
        self.qout = nn.Linear(self.n_qubits, self.output_size)
        
    @property
    def circuit(self):
        raise NotImplementedError('Should init circuit')

# %%
def measure(self):
    HamiZ = [ PauliOperator({f'Z{i}': 1}) for i in range(len(self.qubits)) ]
    res = [ eval(qop(self.circuit, Hami, self.machine, self.qubits))[0,0] for Hami in HamiZ ]
    
    return Parameter(Tensor(res[:self.n_qubits]))

QuantumLayerBase.measure = measure

# %%
def forward(self, inputs):
    y_t = self.qin(Parameter(inputs))
    self.data = y_t[0]
    
    return self.qout(self.measure())

QuantumLayerBase.forward = forward

# %% [markdown]
# ### 2.2.2 Quantum Layer Design

# %%
class QuantumLayer(QuantumLayerBase):
    def __init__(self, input_size, output_size, *, n_qubits, degree = 1, n_layers = 1, ctx = None):
        super(QuantumLayer, self).__init__(input_size, output_size, 
                                         n_qubits = n_qubits, n_layers = n_layers, ctx = ctx)
        
        self.degree = degree
        self.angles = Parameter(torch.rand(n_layers + 1, degree, self.n_qubits))
        
    @property
    def circuit(self):
        if self.data == None:
            raise ValueError('Need to feed a input data!')
        
        n = self.n_qubits
        q = self.qubits
        x = self.data
        p = self.angles
        degree = self.degree
        
        # quantum gates - must use small case!
        identity = VariationalQuantumGate_I
        h = VariationalQuantumGate_H
        ry = VariationalQuantumGate_RY
        cz = VariationalQuantumGate_CZ
        u = [
            None,
            VariationalQuantumGate_U1,
            VariationalQuantumGate_U2,
            VariationalQuantumGate_U3
        ]
        
        # init variational quantum circuit
        vqc = VariationalQuantumCircuit()

        # in order to use each qubits => when n_qubits < len(ctx.qubits)
        [ vqc.insert(identity(q[i])) for i in range(len(q)) ]
        
        [ vqc.insert( h(q[i]) ) for i in range(n) ]
        [ vqc.insert( ry(q[i], var(x[i] * torch.pi / 2)) ) for i in range(n) ]
        [ vqc.insert( u[degree](q[i], *[ var(p[0][d][i]) for d in range(degree) ]) ) 
                 for i in range(n) ]
        
        for layer in range(self.n_layers):
            for i in range(n - 1):
                vqc.insert(cz(q[i], q[i + 1]))
            vqc.insert(cz(q[n - 1], q[0]))
            
            [ vqc.insert( u[degree](q[i], *[ var(p[layer + 1][d][i]) for d in range(degree) ]) ) 
                 for i in range(n) ]
        
        return vqc

# %% [markdown]
# ## 2.3 Quantum-LSTM

# %%
class QLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, *, ctx, mode='classical'):
        super().__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.ctx = ctx
        self.mode = mode
        
        # Parameters: angles
        #  => Q * (n + 1) * degree
        
        # input gates
        self.input_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                        n_qubits = 4, n_layers = 2, degree = 3, ctx = ctx) # 36
        # forget gates
        self.forget_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                         n_qubits = 5, n_layers = 2, degree = 3, ctx = ctx) # 45
        # cell - select memory
        self.select_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                       n_qubits = 4, n_layers = 2, degree = 3, ctx = ctx) # 36
        # output gates
        self.output_circuit = QuantumLayer(input_size + hidden_size, hidden_size, 
                                         n_qubits = 3, n_layers = 2, degree = 2, ctx = ctx) # 18

# %%
def forward(self, inputs, init_states = None):
    sequence_size, batch_size, _ = inputs.size()
    hidden_sequence = []
    
    if init_states == None:
        h_t, c_t = (
            torch.zeros(1, batch_size, self.hidden_size).to(inputs.device),
            torch.zeros(1, batch_size, self.hidden_size).to(inputs.device),
        )
    else:
        h_t, c_t = init_states
        
    for t in range(sequence_size):
        x_t = inputs[t, :, :]
        
        if self.mode == 'GRU':
            v_t = torch.cat((h_t[0], x_t), dim = 1)
            
            # update gates
            z_t = torch.sigmoid(self.forget_circuit(v_t))
            # reset gates
            r_t = torch.sigmoid(self.output_circuit(v_t))
        
            v_hat_t = torch.cat(((r_t * h_t)[0], x_t), dim = 1)
            g_t = torch.tanh(self.select_circuit(v_hat_t))
            h_t = (z_t * g_t) + (1 - z_t) * h_t 
        
        hidden_sequence.append(h_t)
        
    # reshape hidden_seq p/ retornar
    #
    # [tensor([[[0.0444, ...]]] => tensor([[[0.0444, ...]]]
    # 
    hidden_sequence = torch.cat(hidden_sequence, dim = 0)
    
    return hidden_sequence, (h_t, c_t)

QLSTM.forward = forward

# %% [markdown]
# ## 2.4 Stacked QLSTM

# %%
from collections import OrderedDict

class StackedQLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, *, num_layers = 1, ctx = None, mode = 'classical'):
        super().__init__()
        
        self.qlstms = nn.Sequential(OrderedDict([
            (f'QLSTM{i + 1}', QLSTM(input_size if i == 0 else hidden_size , hidden_size, ctx = ctx, mode = mode)) 
                for i in range(num_layers)
        ]))
        

    def forward(self, inputs, parameters = None):
        outputs = None
        
        for i, qlstm in enumerate(self.qlstms):
            if i != 0:
                inputs = outputs
            
            outputs, parameters = qlstm(inputs, parameters)
        
        return outputs, parameters

# %% [markdown]
# # 3. Quantum Model and Train

# %%
class QModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_output, *, num_layers = 1, ctx = None, mode = 'classical'):
        super(QModel, self).__init__()
        
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        self.qlstm = StackedQLSTM(input_size, hidden_size, 
                                  num_layers = num_layers, ctx = ctx, mode = mode)
        self.predict = nn.Linear(hidden_size, num_output)

    def forward(self, x):
        x = x.unsqueeze(0)
        
        # sequence lenth , batch_size, features length
        # 
        h0 = torch.zeros(1, x.size(1), self.hidden_size)
        c0 = torch.zeros(1, x.size(1), self.hidden_size)
        
        out, _ = self.qlstm(x, (h0, c0))
        out = self.predict(out[0])
        
        return out

# %% [markdown]
# ## 3.1 train QModel

# %%
from torch.utils.data import RandomSampler

def train_model(model, datas, batch_size, *, loss_func, optimizer, epoch = 50):
    losses = []
    sampler = RandomSampler(datas, num_samples = batch_size)
    
    for step in range(epoch):
        train_loss = 0.0
        
        for index in sampler:
            batch_x, batch_y = datas[index][0], datas[index][1]
            b_x = batch_x.unsqueeze(0)
            b_y = batch_y.unsqueeze(0)
            
            output = model(b_x)

            loss = loss_func(output, b_y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        print(f'Epoch {step + 1}/{epoch}: Loss: {train_loss / batch_size}')
        losses.append(train_loss / batch_size)
    
    return losses

# %% [markdown]
# ## 3.2 Evaluate Model

# %%
def calculate_E(actual, predict):
    E = actual[0] - predict[0]
    E = torch.norm(Tensor(E))
    E /= torch.norm(Tensor(predict))
    
    return E

def calculate_accuarcy(model, X_test, y_test, scaler=test_scaler):
    n = len(X_test)
    
    err = 0.0
    for i in range(0, n):
        err += calculate_E(
            scaler.inverse_transform(y_test[i:i + 1].data), # actual
            scaler.inverse_transform(model(X_test[i:i + 1]).data) # predict
        ) ** 2
    err /= n
    
    return 1 - err ** 0.5

# %% [markdown]
# ## 3.3 Train Model

# %%
features_size = 4
window_size = features_size * 3 # 
predict_size = features_size # features

input_size = window_size
num_output = predict_size

hidden_size = 32
num_layers = 2

# %%
best_score = 0
count = 1
for lr in list(range(30, 71, 1)):
    lr = lr / 10000
    print('-' * 20)
    print('count:', count)
    print('selected hidden_size: ', hidden_size)
    print('selected num_layers: ', num_layers)
    print('selected lr: ', lr)
    count += 1
    qmodel = QModel(input_size, hidden_size, num_output, 
        num_layers = num_layers, ctx = ctx, mode='GRU')
    optimizer = torch.optim.AdamW(qmodel.parameters(), lr = lr)
    loss_func = nn.MSELoss()

    losses = train_model(qmodel, train_data, batch_size=20,          
                   loss_func = loss_func, optimizer = optimizer, epoch = 50)
    score = calculate_accuarcy(qmodel, X_test, y_test).numpy()
    if score > best_score:
        best_score = score
        best_parameters = {
            'hidden_size': hidden_size,
            'num_layers': num_layers,
            'lr': lr
        }
    print()

print("Best score: ", best_score)
print("Best parameters: ", best_parameters)
# Out:
# --------------------
# count: 1
# selected hidden_size:  32
# selected num_layers:  2
# selected lr:  0.003
# Epoch 1/50: Loss: 0.994255644083023
# Epoch 2/50: Loss: 1.0208078145980835
# Epoch 3/50: Loss: 0.9247243255376816
# Epoch 4/50: Loss: 0.9200459539890289
# Epoch 5/50: Loss: 0.8679194808006286
# Epoch 6/50: Loss: 0.8421904385089874
# Epoch 7/50: Loss: 0.7378145068883896
# Epoch 8/50: Loss: 0.6219734266400337
# Epoch 9/50: Loss: 0.5622272357344628
# Epoch 10/50: Loss: 0.5002650059759617
# Epoch 11/50: Loss: 0.4208501871675253
# Epoch 12/50: Loss: 0.4149302802979946
# Epoch 13/50: Loss: 0.27006525043398144
# Epoch 14/50: Loss: 0.36995451506227256
# Epoch 15/50: Loss: 0.323038462921977
# Epoch 16/50: Loss: 0.3741777216549963
# Epoch 17/50: Loss: 0.3361961020156741
# Epoch 18/50: Loss: 0.2399273855611682
# Epoch 19/50: Loss: 0.21026975000277162
# Epoch 20/50: Loss: 0.25568852927535773
# Epoch 21/50: Loss: 0.2710087390616536
# Epoch 22/50: Loss: 0.2436539559625089
# Epoch 23/50: Loss: 0.19966017883270978
# Epoch 24/50: Loss: 0.24176070298999547
# Epoch 25/50: Loss: 0.14665617579594253
# Epoch 26/50: Loss: 0.13439347902312876
# Epoch 27/50: Loss: 0.21308816415257753
# Epoch 28/50: Loss: 0.1292031355551444
# Epoch 29/50: Loss: 0.1915507928468287
# Epoch 30/50: Loss: 0.13270158404484392
# Epoch 31/50: Loss: 0.09008518233895302
# Epoch 32/50: Loss: 0.07978230807930231
# Epoch 33/50: Loss: 0.0646524052368477
# Epoch 34/50: Loss: 0.042365450388751925
# Epoch 35/50: Loss: 0.03893390982411802
# Epoch 36/50: Loss: 0.03195728776045144
# Epoch 37/50: Loss: 0.016840935601794626
# Epoch 38/50: Loss: 0.016001741894433506
# Epoch 39/50: Loss: 0.011458351064356975
# Epoch 40/50: Loss: 0.007008643716108054
# Epoch 41/50: Loss: 0.0014986549489549362
# Epoch 42/50: Loss: 0.001015207670570817
# Epoch 43/50: Loss: 0.0007052762557577807
# Epoch 44/50: Loss: 0.0010372012955485843
# Epoch 45/50: Loss: 0.0010699465467041592
# Epoch 46/50: Loss: 0.0014425509027205408
# Epoch 47/50: Loss: 0.0008003909209946869
# Epoch 48/50: Loss: 0.0008662880247356953
# Epoch 49/50: Loss: 0.0008671891391713871
# Epoch 50/50: Loss: 0.001062208760777139
#
# Best score:  0.9845617
# Best parameters:  {'hidden_size': 32, 'num_layers': 2, 'lr': 0.0035}

# %%
qmodel = QModel(input_size, hidden_size, num_output, 
                num_layers = num_layers, ctx = ctx, mode='GRU')
optimizer = torch.optim.Adam(qmodel.parameters(), lr = 0.008)
loss_func = nn.MSELoss()

start = time.time()
losses = train_model(qmodel, train_data, batch_size=20,          
               loss_func = loss_func, optimizer = optimizer, epoch = 15)

end = time.time()

print(f'time costs: {end - start}')
# Out:
# Epoch 1/15: Loss: 1.0876947104930879
# Epoch 2/15: Loss: 0.9598034292459487
# Epoch 3/15: Loss: 0.8351614743471145
# Epoch 4/15: Loss: 0.6870085507631302
# Epoch 5/15: Loss: 0.463780040666461
# Epoch 6/15: Loss: 0.20249801836616826
# Epoch 7/15: Loss: 0.40852362422447186
# Epoch 8/15: Loss: 0.28391173090785743
# Epoch 9/15: Loss: 0.17730942342022898
# Epoch 10/15: Loss: 0.08707691778072331
# Epoch 11/15: Loss: 0.031092416431056334
# Epoch 12/15: Loss: 0.03329774774392717
# Epoch 13/15: Loss: 0.005920715473257588
# Epoch 14/15: Loss: 0.0015338709399657091
# Epoch 15/15: Loss: 0.0006087399824536988
# time costs: 69.793860912323

# %%
qmodel.load_state_dict(torch.load("./model/qmodel_gru2.pt"))
optimizer = torch.optim.Adam(qmodel.parameters(), lr = 0.005)
loss_func = nn.MSELoss()

start = time.time()
losses = train_model(qmodel, train_data, batch_size=20,          
               loss_func = loss_func, optimizer = optimizer, epoch = 2)

end = time.time()

print(f'time costs: {end - start}')
# Out:
# Epoch 1/2: Loss: 0.004582978755570366
# Epoch 2/2: Loss: 0.0016391626675613224
# time costs: 9.189946174621582

# %%
with open('loss/GRU/loss10.pkl', 'wb') as pkl_file:
    pickle.dump(losses, pkl_file)

# %%
import matplotlib.pyplot as plt

plt.plot(losses, color="#FF6666")

# %%
calculate_accuarcy(qmodel, X_test, y_test)
# Out:
# tensor(0.9806)

# %% [markdown]
# ### - Save the Model

# %%
# save the model
# 9846
torch.save(qmodel.state_dict(), "./model/qmodel_gru2.pt")

# %% [markdown]
# ### - Load the Model

# %%
features_size = 4
window_size = features_size * 3 # 
predict_size = features_size # features

input_size = window_size
num_output = predict_size

hidden_size = 32
num_layers = 2

# loaded quantum model
loaded_qmodel = QModel(input_size, hidden_size, num_output, 
                num_layers = num_layers, ctx = ctx, mode='GRU')

# %%
loaded_qmodel.load_state_dict(torch.load("./model/qmodel_gru.pt"))
# Out:
# <All keys matched successfully>

# %%
loaded_qmodel
# Out:
# QModel(
#   (qlstm): StackedQLSTM(
#     (qlstms): Sequential(
#       (QLSTM1): QLSTM(
#         (input_circuit): QuantumLayer(
#           (qin): Linear(in_features=44, out_features=4, bias=True)
#           (qout): Linear(in_features=4, out_features=32, bias=True)
#         )
#         (forget_circuit): QuantumLayer(
#           (qin): Linear(in_features=44, out_features=5, bias=True)
#           (qout): Linear(in_features=5, out_features=32, bias=True)
#         )
#         (select_circuit): QuantumLayer(
#           (qin): Linear(in_features=44, out_features=4, bias=True)
#           (qout): Linear(in_features=4, out_features=32, bias=True)
#         )
#         (output_circuit): QuantumLayer(
#           (qin): Linear(in_features=44, out_features=3, bias=True)
#           (qout): Linear(in_features=3, out_features=32, bias=True)
#         )
#       )
#       (QLSTM2): QLSTM(
#         (input_circuit): QuantumLayer(
#           (qin): Linear(in_features=64, out_features=4, bias=True)
#           (qout): Linear(in_features=4, out_features=32, bias=True)
#         )
#         (forget_circuit): QuantumLayer(
#           (qin): Linear(in_features=64, out_features=5, bias=True)
#           (qout): Linear(in_features=5, out_features=32, bias=True)
#         )
#         (select_circuit): QuantumLayer(
#           (qin): Linear(in_features=64, out_features=4, bias=True)
#           (qout): Linear(in_features=4, out_features=32, bias=True)
#         )
#         (output_circuit): QuantumLayer(
#           (qin): Linear(in_features=64, out_features=3, bias=True)
#           (qout): Linear(in_features=3, out_features=32, bias=True)
#         )
#       )
#     )
#   )
#   (predict): Linear(in_features=32, out_features=4, bias=True)
# )

# %%
calculate_accuarcy(loaded_qmodel, X_test, y_test)
# Out:
# tensor(0.9796)

# %% [markdown]
# ### - statistic summary

# %%
# training time:
# 229.86167073249817
# 231.0602912902832

# 222.75650191307068
# 221.82216429710388

# 229.31373858451843
# 229.7402262687683

# 230.11960411071777
# 228.9458122253418

# 2225.84280276298523
# 239.6934380531311

# %%
average_time = np.mean([
    229.86167073249817, 231.0602912902832, 222.75650191307068,
    221.82216429710388, 229.31373858451843, 229.7402262687683,
    230.11960411071777, 228.9458122253418, 225.84280276298523,
    239.6934380531311
])
average_time
# Out:
# 228.91562502384187

# %%
# accuary:
# tensor(0.9803)
# tensor(0.9840)

# tensor(0.9839)
# tensor(0.9807)

# tensor(0.9812)
# tensor(0.9834)

# tensor(0.9803)
# tensor(0.9846)

# tensor(0.9818)
# tensor(0.9814)

# %%
average_accuary = np.mean([
    0.9803, 0.9840, 0.9839, 0.9807, 0.9812,
    0.9834, 0.9803, 0.9846, 0.9818, 0.9814
])
average_accuary
# Out:
# 0.98216

# %% [markdown]
# # 6. Plot Result

# %%
results = []

for i in range(0, len(X_test), features_size):
    input_data = X_test[i:i+1]
    result = loaded_qmodel(input_data)
    result = test_scaler.inverse_transform(result.data)
    
    results.append(result[0])

# %% [markdown]
# ## - plot each feature

# %%
plt.figure(figsize=(20, 7))
plt.plot(test['meantemp'])
meantemp = [ r[0] for r in results ] 
meantemp = [None, None, None, None] + meantemp
plt.plot(meantemp, color="red")
plt.show()

# %%
plt.figure(figsize=(20, 7))
plt.plot(test['humidity'])
humidity = [ r[1] for r in results ] 
humidity = [None, None, None, None] + humidity
plt.plot(humidity, color="red")
plt.show()

# %%
plt.figure(figsize=(20, 7))
plt.plot(test['wind_speed'])
wind_speed = [ r[2] for r in results ] 
wind_speed = [None, None, None, None] + wind_speed
plt.plot(wind_speed, color="red")
plt.show()

# %%
plt.figure(figsize=(20, 7))
plt.plot(test['meanpressure'])
meanpressure = [ r[3] for r in results ] 
meanpressure = [None, None, None, None] + meanpressure
plt.plot(meanpressure, color="red")
plt.show()

# %%
plt.plot(test)
# Out:
# [<matplotlib.lines.Line2D at 0x1b5ad6cbc70>,
#  <matplotlib.lines.Line2D at 0x1b5ad6cbd90>,
#  <matplotlib.lines.Line2D at 0x1b5ad6cbe50>,
#  <matplotlib.lines.Line2D at 0x1b5ad6cbf10>]

# %%
plt.plot(results)
# Out:
# [<matplotlib.lines.Line2D at 0x1b5c221d2e0>,
#  <matplotlib.lines.Line2D at 0x1b5c221d400>,
#  <matplotlib.lines.Line2D at 0x1b5c221d4c0>,
#  <matplotlib.lines.Line2D at 0x1b5c221d580>]

# %%
test1 = pd.DataFrame(test, columns=('meantemp', 'humidity', 'wind_speed'))
test2 = pd.DataFrame(test, columns=('meanpressure',))

# %%
plt.plot(test1)
# Out:
# [<matplotlib.lines.Line2D at 0x1b5c2273eb0>,
#  <matplotlib.lines.Line2D at 0x1b5c2273fd0>,
#  <matplotlib.lines.Line2D at 0x1b5c227e0d0>]

# %%
plt.plot(test2)

# %%
results = pd.DataFrame(results)
results.columns = ('meantemp', 'humidity', 'wind_speed', 'meanpressure')
results
# Out:
#       meantemp   humidity  wind_speed  meanpressure
# 0     2.814166  77.417207    0.406879   1015.941518
# 1     6.043743  73.360358    1.426855   1016.185341
# 2     8.566611  71.702712    1.424796   1014.837099
# 3     7.541678  74.181249    3.029264   1012.048548
# 4     2.650720  86.700829    2.522225   1004.826865
# ..         ...        ...         ...           ...
# 105  38.439103  34.309962    7.800905   1015.762973
# 106  44.279855  29.734406    8.225763   1013.920682
# 107  45.685544  28.061484    8.939284   1013.006399
# 108  40.623158  32.869271    8.979624   1013.067609
# 109  37.233058  39.324662    8.389871   1011.099339
#
# [110 rows x 4 columns]

# %%
result1 = pd.DataFrame(results, columns=('meantemp', 'humidity', 'wind_speed'))
result2 = pd.DataFrame(results, columns=('meanpressure',))

# %%
plt.plot(test1)
# Out:
# [<matplotlib.lines.Line2D at 0x1b5c1932850>,
#  <matplotlib.lines.Line2D at 0x1b5c1932970>,
#  <matplotlib.lines.Line2D at 0x1b5c1932a30>]

# %%
plt.plot(result1)
# Out:
# [<matplotlib.lines.Line2D at 0x1b5c1984df0>,
#  <matplotlib.lines.Line2D at 0x1b5c1984f10>,
#  <matplotlib.lines.Line2D at 0x1b5c1984fd0>]

# %%
plt.plot(result1)
# Out:
# [<matplotlib.lines.Line2D at 0x1b5c22ca6d0>,
#  <matplotlib.lines.Line2D at 0x1b5c22ca7f0>,
#  <matplotlib.lines.Line2D at 0x1b5c22ca8b0>]

# %%
plt.plot(test2)

# %%
plt.plot(result2)
